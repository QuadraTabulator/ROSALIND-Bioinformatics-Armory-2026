# %% [markdown]
# # Strings & Nucleotides

# %% [markdown]
# ## Study

# %%
print('Hello')
# Out:
# Hello

# %%
a='Hello'

# %%
a
# Out:
# 'Hello'

# %%
DNAstring='...'

# %% [markdown]
# Given: A DNA string s
#  of length at most 1000 nt.
#
# Return: Four integers (separated by spaces) counting the respective number of times that the symbols 'A', 'C', 'G', and 'T' occur in
# s
# .

# %% [markdown]
# **My solution 2:** For each occurrence of A in the string, increment a counter by 1. At the end of the string, save the counter number as a variable Acount. Repeat for C, G, and T.
#
# OR: string.count() for "string" = desired string does this automatically. Built-in feature. (count())

# %%
DNAstring='...'
# save provided string as Python string

# %%
Acount = DNAstring.count('A')
# Number of occurrences of A in string DNAstring. Save as variable

# %%
Ccount = DNAstring.count('C')

# %% [markdown]
# Tcount = DNAstring.count('T')

# %%
Gcount = DNAstring.count('G')

# %%
print(Acount, Ccount, Gcount, Tcount)
# Out:
# 248 221 216 211

# %%
len(DNAstring) == Acount + Ccount + Gcount + Tcount
# Confirm that provided string's length & the sum of A, C, G, and T counts are equal
# Out:
# True

# %% [markdown]
# To do:
# - How to find location of this notebook file? Use os.getcwd

# %% [markdown]
# ### Misc (os/dir testing)

# %%
import os

# %%
# os.chdir('/Users/dfung/Documents/Bioinformatics dump/Python Projects/ROSALIND Training/Bioinformatics Armory')

# %%
os.getcwd()
# Out:
# '/Users/dfung/Documents/Bioinformatics dump/Python Projects/ROSALIND Training/Bioinformatics Armory'

# %% [markdown]
# ## Study 2: Bioinformatics Armory

# %%
from Bio.Seq import Seq

# %%
my_seq=Seq("AGTACACTGGT")
my_seq.count("A")
# Out:
# 3

# %% [markdown]
# ## Execution

# %%
data_Seq=Seq("...")
data_Out=print(
    data_Seq.count("A"),
    data_Seq.count("C"),
    data_Seq.count("G"),
    data_Seq.count("T")
)
# Out:
# 239 204 225 241

# %%
data_Out2=[data_Seq.count("A"),data_Seq.count("C"),data_Seq.count("G"),data_Seq.count("T")]
# data_Out2
print(*data_Out2,sep=" ")
# Stored counts into a list; * acts as an unpacker.
# Out:
# 239 204 225 241
